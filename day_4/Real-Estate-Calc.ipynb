# %%
class Rental_calculator:
    def __init__(self):
        self.income = self.income()
        self.expenses = self.expenses()
        self.cash_flow = self.cash_flow()
        self.cash_on_roi = self.cash_on_roi()
        self.totalroi = self.totalroi
        
    def income(self):
        income_info = {
            'Rental Income': 0, 
            'Laundry': 0, 
            'Storage': 0, 
            'Misc': 0
        }
        #Asking user for information for income
        for k in income_info.keys():
            income_input = float(input(f'What is your income for {k}? '))
            income_info[k] = income_input
            income_total += income_input
        income_info['Total'] = income_total
        return income_info

    def expenses(self):
        expenses_info = {
            'Morgage': 0,
            'Taxes': 0,
            'Insurance': 0,
            'Utilities': 0,
            'HOA Fees': 0,
            'Lawn Care': 0,
            'Vacancy AKA: No Tenents': 0,
            'Repair Costs': 0,
            'Cap X': 0,
        }
        #Asking user for information on expenses
        exp_total = 0
        for k in expenses_info.keys():
            exp_input = float(input(f'What is your expense for {k}? '))
            expenses_info[k] = exp_input
            exp_total += exp_input
        expenses_info['Total'] = exp_total
        return expenses_info
        
    
    
    
    def cash_flow(self):
        cash_flow_info = self.income['Total'] - self.expenses['Total']
        return cash_flow_info
        
    def cash_on_cash_roi(self):
        cash_on_cash_roi = {
            'Down Payment': 0,
            'Closing Cost': 0,    #total investment/// cash flow *12 / percent * total
            'Rehab Budget': 0,
            }
        
        roi_total = 0
        for k in expenses_info.keys():
            roi_input = float(input(f'What is your expense for {k}? '))
            cash_on_cash_roi[k] = roi_input
            roi_total += roi_input
        cash_on_cash_roi['Total'] = roi_total
        return cash_on_cash_roi
         #self.total_investment = total_investment 
        
        
    def totalroi(self):
        pass
        
calc = Rental_calculator()
# calc.income()
# calc.expenses()
# calc.cash_flow()
# calc.cash_on_cash_roi()


        
        
#     while True:
        
#         selection = input(
#             '\n To view the final results, type: "view"'
#             '\n To edit your information you entered, type: "edit"'
#             '\n To finish the calculations type: "exit"').lower()
        
#         while selection not in ['view', 'edit', 'finish']:
#             selection = input('\n Please enter either "view", "edit" or "finish"\n').lower()
            
#             if selection == 'view':
#                 rental.view_results()
            
#             elif selction == 'edit':
#                 rental.edit_input()
            
#             elif selection == 'finish':
#                 break
# Out:
# What is your income for Rental Income? 1
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-39-4b0c2ed4c56d> in <module>
#      70         pass
#      71
# ---> 72 calc = Rental_calculator()
#      73 # calc.income()
#      74 # calc.expenses()
#
# <ipython-input-39-4b0c2ed4c56d> in __init__(self)
#       1 class Rental_calculator:
#       2     def __init__(self):
# ----> 3         self.income = self.income()
#       4         self.expenses = self.expenses()
#       5         self.cash_flow = self.cash_flow()
#
# <ipython-input-39-4b0c2ed4c56d> in income(self)
#      18             income_input = float(input(f'What is your income for {k}? '))
#      19             income_info[k] = income_input
# ---> 20             income_total += income_input
#      21         income_info['Total'] = income_total
#      22         return income_info
#
# ...
